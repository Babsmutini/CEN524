# %% [markdown]
# ### ASSIGNMENT USING THE LOAD_BREAST_CANCER DATASET AND TENSOR FLOW

# %%
# Import libraries
import numpy as np
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
import pandas as pd

# Load Iris dataset
iris = load_iris()
X = pd.DataFrame(data=iris.data[:125, :], columns=iris.feature_names)
y = pd.DataFrame(data=iris.target[:125], columns=['irisType'])

# Convert target variable to one-hot encoding
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y['irisType'])
y_one_hot = to_categorical(y_encoded)

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)

# Define model
model = Sequential([
    Dense(10, input_shape=(4,), activation='relu'),
    Dense(3, activation='softmax')  # Output layer with softmax for multiclass classification
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train, y_train, epochs=50, verbose=1)

# Evaluate model
loss, accuracy = model.evaluate(X_test, y_test)
print("Accuracy:", accuracy)

# Predict and generate confusion matrix
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

from sklearn.metrics import confusion_matrix
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred_classes))
# Out:
# 2024-05-15 14:48:04.521596: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/50
# 4/4 [==============================] - 3s 22ms/step - loss: 1.6763 - accuracy: 0.2100
# Epoch 2/50
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6022 - accuracy: 0.2100
# Epoch 3/50
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5289 - accuracy: 0.2100
# Epoch 4/50
# 4/4 [==============================] - 0s 11ms/step - loss: 1.4730 - accuracy: 0.2100
# Epoch 5/50
# 4/4 [==============================] - 0s 19ms/step - loss: 1.4137 - accuracy: 0.2100
# Epoch 6/50
# 4/4 [==============================] - 0s 99ms/step - loss: 1.3638 - accuracy: 0.1900
# Epoch 7/50
# 4/4 [==============================] - 0s 136ms/step - loss: 1.3201 - accuracy: 0.1200
# Epoch 8/50
# 4/4 [==============================] - 0s 12ms/step - loss: 1.2787 - accuracy: 0.0400
# Epoch 9/50
# 4/4 [==============================] - 0s 46ms/step - loss: 1.2444 - accuracy: 0.0200
# Epoch 10/50
# 4/4 [==============================] - 0s 97ms/step - loss: 1.2153 - accuracy: 0.0600
# Epoch 11/50
# 4/4 [==============================] - 0s 31ms/step - loss: 1.1883 - accuracy: 0.1500
# Epoch 12/50
# 4/4 [==============================] - 0s 39ms/step - loss: 1.1645 - accuracy: 0.2300
# Epoch 13/50
# 4/4 [==============================] - 0s 83ms/step - loss: 1.1413 - accuracy: 0.2800
# Epoch 14/50
# 4/4 [==============================] - 0s 15ms/step - loss: 1.1207 - accuracy: 0.3500
# Epoch 15/50
# 4/4 [==============================] - 1s 165ms/step - loss: 1.1009 - accuracy: 0.3700
# Epoch 16/50
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0823 - accuracy: 0.3700
# Epoch 17/50
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0643 - accuracy: 0.3700
# Epoch 18/50
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0471 - accuracy: 0.3700
# Epoch 19/50
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0312 - accuracy: 0.3700
# Epoch 20/50
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0158 - accuracy: 0.3700
# Epoch 21/50
# 4/4 [==============================] - 0s 15ms/step - loss: 1.0006 - accuracy: 0.3700
# Epoch 22/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9856 - accuracy: 0.3800
# Epoch 23/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9705 - accuracy: 0.3800
# Epoch 24/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.9567 - accuracy: 0.4400
# Epoch 25/50
# 4/4 [==============================] - 0s 21ms/step - loss: 0.9425 - accuracy: 0.6100
# Epoch 26/50
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9291 - accuracy: 0.7600
# Epoch 27/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9143 - accuracy: 0.8000
# Epoch 28/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8982 - accuracy: 0.8400
# Epoch 29/50
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8798 - accuracy: 0.8600
# Epoch 30/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8598 - accuracy: 0.8800
# Epoch 31/50
# 4/4 [==============================] - 0s 32ms/step - loss: 0.8371 - accuracy: 0.8900
# Epoch 32/50
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8141 - accuracy: 0.9100
# Epoch 33/50
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7950 - accuracy: 0.9100
# Epoch 34/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7834 - accuracy: 0.9200
# Epoch 35/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7733 - accuracy: 0.9200
# Epoch 36/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7630 - accuracy: 0.9100
# Epoch 37/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7531 - accuracy: 0.9200
# Epoch 38/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7440 - accuracy: 0.9300
# Epoch 39/50
# 4/4 [==============================] - 0s 10ms/step - loss: 0.7353 - accuracy: 0.9500
# Epoch 40/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7263 - accuracy: 0.9500
# Epoch 41/50
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7177 - accuracy: 0.9500
# Epoch 42/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7093 - accuracy: 0.9500
# Epoch 43/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7015 - accuracy: 0.9500
# Epoch 44/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.9500
# Epoch 45/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6855 - accuracy: 0.9500
# Epoch 46/50
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6774 - accuracy: 0.9400
# Epoch 47/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6697 - accuracy: 0.9500
# Epoch 48/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.9500
# Epoch 49/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6547 - accuracy: 0.9400
# Epoch 50/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6474 - accuracy: 0.9400
# 1/1 [==============================] - 2s 2s/step - loss: 0.6056 - accuracy: 0.9600
# Accuracy: 0.9599999785423279
# 1/1 [==============================] - 0s 339ms/step
# Confusion Matrix:
#  [[13  0  0]
#  [ 0  8  0]
#  [ 0  1  3]]
